# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresCMontejo/PANDAS_I-O/blob/main/Panda_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Leyendo archivos CSV**

# %% [markdown]
# ### **Importando archivos CSV**

# %%
import pandas as pd

# %%
datos = pd.read_csv('/content/drive/MyDrive/ETL/PANDAS/PANDAS I O/superstore_data.csv')
datos.head(5)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
dato1 = pd.read_csv('/content/drive/MyDrive/ETL/PANDAS/PANDAS I O/superstore_data_punto_coma.csv')
dato1
# Out:
#      Id;Year_Birth;Education;Marital_Status;Income;Kidhome;Teenhome;Dt_Customer;Recency;MntWines;MntFruits;MntMeatProducts;MntFishProducts;MntSweetProducts;MntGoldProds;NumDealsPurchases;NumWebPurchases;NumCatalogPurchases;NumStorePurchases;NumWebVisitsMonth;Response;Complain
# 0     1826;1970;Graduation;Divorced;84835;0;0;6/16/2...
# 1     1;1961;Graduation;Single;57091;0;0;6/15/2014;0...
# 2     10476;1958;Graduation;Married;67267;0;1;5/13/2...
# 3     1386;1967;Graduation;Together;32474;1;1;11/5/2...
# 4     5371;1989;Graduation;Single;21474;1;0;8/4/2014...
# ...                                                 ...
# 2235  10142;1976;PhD;Divorced;66476;0;1;7/3/2013;99;...
# 2236  5263;1977;2n Cycle;Married;31056;1;0;1/22/2013...
# 2237  22;1976;Graduation;Divorced;46310;1;0;3/12/201...
# 2238  528;1978;Graduation;Married;65819;0;0;11/29/20...
# 2239  4070;1969;PhD;Married;94871;0;2;1/9/2012;99;16...
#
# [2240 rows x 1 columns]

# %%
#solucion al codigo anterior.
dato1 = pd.read_csv('/content/drive/MyDrive/ETL/PANDAS/PANDAS I O/superstore_data_punto_coma.csv', sep=';')
dato1
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %%
#parametro
#nrows, cantidad de fila que se desea leer, similar a .head()
datos_primeras_filas = pd.read_csv('/content/drive/MyDrive/ETL/PANDAS/PANDAS I O/superstore_data.csv', nrows = 5)
datos_primeras_filas
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ...

# %%
#usecols, para trabajar con columnas
datos_columnas = pd.read_csv('/content/drive/MyDrive/ETL/PANDAS/PANDAS I O/superstore_data.csv', usecols=['Id','Year_Birth','Income'])
datos_columnas1 = pd.read_csv('/content/drive/MyDrive/ETL/PANDAS/PANDAS I O/superstore_data.csv', usecols=[0,1,4]) #tambien se puede seleccionar por indice
datos_columnas
datos_columnas1
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
#Para guardar en csv
datos_columnas1.to_csv('clientes_mercados.csv')

# %%
clientes_mercados = pd.read_csv('/content/clientes_mercados.csv')
clientes_mercados
#El resultado nos da una columna extra
# Out:
#       Unnamed: 0     Id  Year_Birth   Income
# 0              0   1826        1970  84835.0
# 1              1      1        1961  57091.0
# 2              2  10476        1958  67267.0
# 3              3   1386        1967  32474.0
# 4              4   5371        1989  21474.0
# ...          ...    ...         ...      ...
# 2235        2235  10142        1976  66476.0
# 2236        2236   5263        1977  31056.0
# 2237        2237     22        1976  46310.0
# 2238        2238    528        1978  65819.0
# 2239        2239   4070        1969  94871.0
#
# [2240 rows x 4 columns]

# %%
#eliminando el indice que se genera en el archivo csv
datos_columnas1.to_csv('clientes_mercados_sinindice.csv', index=False)

# %%
datos_mercados = pd.read_csv('/content/clientes_mercados_sinindice.csv')
datos_mercados
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# ## **Leyendo archivos EXCEL**

# %% [markdown]
# ### **Importando archivo EXCEL**

# %%
import pandas as pd

# %%
archivo = '/content/drive/MyDrive/ETL/PANDAS/PANDAS I O/emisiones_CO2.xlsx'

# %%
datos_co2 = pd.read_excel(archivo)
datos_co2.head()
# Out:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  Cemento  \
# 0  Afganistán                AFG  1750    0.0     NaN     NaN  NaN      NaN
# 1  Afganistán                AFG  1751    0.0     NaN     NaN  NaN      NaN
# 2  Afganistán                AFG  1752    0.0     NaN     NaN  NaN      NaN
# 3  Afganistán                AFG  1753    0.0     NaN     NaN  NaN      NaN
# 4  Afganistán                AFG  1754    0.0     NaN     NaN  NaN      NaN
#
#    Quema  Otros  Per Capita
# 0    NaN    NaN         NaN
# 1    NaN    NaN         NaN
# 2    NaN    NaN         NaN
# 3    NaN    NaN         NaN
# 4    NaN    NaN         NaN

# %%
#En excel, se pueden crear hojas debajo de las tabla, pero por ahora no sabemos en que hoja estamos, y no sabemos cuantas hojas tiene el excel
#para ello hacemos lo siguiente
pd.ExcelFile(archivo).sheet_names #sheet_names precisamente significa nombre de hojas.
# Out:
# ['emisiones_C02', 'emisiones_percapita', 'fuentes']

# %%
#Si queremos abrir una hoja en especifico de un archivo excel, se hace lo siguiente.
#supongamos que queremos abrir la hoja de nombre 'emisiones_percapita'
percapita = pd.read_excel(archivo, sheet_name='emisiones_percapita')
percapita.tail()
# Out:
#          País ISO 3166-1 alpha-3   Año      Total     Carbón     Aceite  \
# 63099  Global                WLD  2017  4749682.0  1908857.0  1610910.0
# 63100  Global                WLD  2018  4792753.0  1919213.0  1596350.0
# 63101  Global                WLD  2019  4775633.0  1896468.0  1589920.0
# 63102  Global                WLD  2020  4497423.0  1807760.0  1427353.0
# 63103  Global                WLD  2021  4693699.0  1893923.0  1496614.0
#
#              Gas   Cemento    Quema    Otros
# 63099   940144.0  198416.0  51579.0  39776.0
# 63100   979965.0  204225.0  53634.0  39366.0
# 63101   984878.0  208309.0  56569.0  39490.0
# 63102   963695.0  208844.0  51981.0  37789.0
# 63103  1001585.0  211472.0  52663.0  37443.0

# %%
fuentes = pd.read_excel(archivo, sheet_name='fuentes')
fuentes.tail(5)
# Out:
#          País ISO 3166-1 alpha-3   Año                                 Total  \
# 63099  Global                WLD  2017  CDIAC 2022, BP, and Sum of countries
# 63100  Global                WLD  2018  CDIAC 2022, BP, and Sum of countries
# 63101  Global                WLD  2019  CDIAC 2022, BP, and Sum of countries
# 63102  Global                WLD  2020  CDIAC 2022, BP, and Sum of countries
# 63103  Global                WLD  2021  CDIAC 2022, BP, and Sum of countries
#
#                   Carbón             Aceite                Gas        Cemento  \
# 63099  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63100  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63101  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63102  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63103  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
#
# ...

# %%
#ahora queremos visualizar las primeras columnas, analizando la primera hoja del excel
intervalo = pd.read_excel(archivo, sheet_name='emisiones_C02', usecols='A:D') #en excel las columnas estan representadas por letras, filas por numeros
intervalo.head()
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750    0.0
# 1  Afganistán                AFG  1751    0.0
# 2  Afganistán                AFG  1752    0.0
# 3  Afganistán                AFG  1753    0.0
# 4  Afganistán                AFG  1754    0.0

# %%
#seleccionando filas
intervalo2 = pd.read_excel(archivo, sheet_name='emisiones_C02', usecols='A:D', nrows=10)
intervalo2
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750      0
# 1  Afganistán                AFG  1751      0
# 2  Afganistán                AFG  1752      0
# 3  Afganistán                AFG  1753      0
# 4  Afganistán                AFG  1754      0
# 5  Afganistán                AFG  1755      0
# 6  Afganistán                AFG  1756      0
# 7  Afganistán                AFG  1757      0
# 8  Afganistán                AFG  1758      0
# 9  Afganistán                AFG  1759      0

# %% [markdown]
# ### **Escribiendo archivo Excel**

# %%
intervalo.to_excel('emisiones_CO2_intervalo.xlsx', index= False) #eliminamos los indices

# %%
pd.read_excel('emisiones_CO2_intervalo.xlsx')
# Out:
#              País ISO 3166-1 alpha-3   Año         Total
# 0      Afganistán                AFG  1750  0.000000e+00
# 1      Afganistán                AFG  1751  0.000000e+00
# 2      Afganistán                AFG  1752  0.000000e+00
# 3      Afganistán                AFG  1753  0.000000e+00
# 4      Afganistán                AFG  1754  0.000000e+00
# ...           ...                ...   ...           ...
# 63099      Global                WLD  2017  3.609674e+10
# 63100      Global                WLD  2018  3.682651e+10
# 63101      Global                WLD  2019  3.708256e+10
# 63102      Global                WLD  2020  3.526409e+10
# 63103      Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %% [markdown]
# ## **Trabajando archivos EXCEL online**

# %% [markdown]
# Link: https://docs.google.com/spreadsheets/d/1JFeNgl5mf5MLW0AEMCRqXmDBpt1aMh0F/edit?usp=sharing&ouid=105500710579634221268&rtpof=true&sd=true

# %%
#Para trabajar con archivos de excel de google (google workspace), damos click en compartir y es importante que en acceso general este la opción:
#"cualquier usuario que tenga el vinculo" y en la opción "lector"
"""
en el enlace que se obtiene, es importante solo usar el ID de la hoja de calculo, el id es despues de la d/ del enlace
1JFeNgl5mf5MLW0AEMCRqXmDBpt1aMh0F, y termina antes del /edit?usp=sharing&ouid=105500710579634221268&rtpof=true&sd=true
"""
sheet_id = '1JFeNgl5mf5MLW0AEMCRqXmDBpt1aMh0F'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet' #gvis/tq sirve para comunicar google colab con google excel online
#?tqx=out:csv nos sirve para especificar el formato con el que trabajaremos la hoja de datos, posteriormente se agrega &sheet, si no se especifica la hoja, por default trae la primera hoja

# %%
datos_co2_sheet = pd.read_csv(url)
datos_co2_sheet.head()
# Out:
#          País ISO 3166-1 alpha-3   Año Total Carbón Aceite  Gas Cemento Quema  \
# 0  Afganistán                AFG  1750     0    NaN    NaN  NaN     NaN   NaN
# 1  Afganistán                AFG  1751     0    NaN    NaN  NaN     NaN   NaN
# 2  Afganistán                AFG  1752     0    NaN    NaN  NaN     NaN   NaN
# 3  Afganistán                AFG  1753     0    NaN    NaN  NaN     NaN   NaN
# 4  Afganistán                AFG  1754     0    NaN    NaN  NaN     NaN   NaN
#
#   Otros Per Capita
# 0   NaN        NaN
# 1   NaN        NaN
# 2   NaN        NaN
# 3   NaN        NaN
# 4   NaN        NaN

# %%
#si queremos ver una hoja en especifico en el excel online, hacemos lo siguiente.
sheet_id = '1JFeNgl5mf5MLW0AEMCRqXmDBpt1aMh0F'
sheet_name = 'emisiones_percapita'
url_percapita = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}' #colocamos a lo ultimo la variable "sheet_name"
percapita_sheet = pd.read_csv(url_percapita)
percapita_sheet.head()
# Out:
#          País ISO 3166-1 alpha-3   Año Total Carbón Aceite  Gas Cemento Quema  \
# 0  Afganistán                AFG  1750   NaN    NaN    NaN  NaN     NaN   NaN
# 1  Afganistán                AFG  1751   NaN    NaN    NaN  NaN     NaN   NaN
# 2  Afganistán                AFG  1752   NaN    NaN    NaN  NaN     NaN   NaN
# 3  Afganistán                AFG  1753   NaN    NaN    NaN  NaN     NaN   NaN
# 4  Afganistán                AFG  1754   NaN    NaN    NaN  NaN     NaN   NaN
#
#   Otros
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
sheet_id = '1JFeNgl5mf5MLW0AEMCRqXmDBpt1aMh0F'
sheet_name = 'fuentes'
url_fuentes = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}' #colocamos a lo ultimo la variable "sheet_name"
fuentes_sheet = pd.read_csv(url_fuentes)
fuentes_sheet.tail()
# Out:
#          País ISO 3166-1 alpha-3   Año                                 Total  \
# 63099  Global                WLD  2017  CDIAC 2022, BP, and Sum of countries
# 63100  Global                WLD  2018  CDIAC 2022, BP, and Sum of countries
# 63101  Global                WLD  2019  CDIAC 2022, BP, and Sum of countries
# 63102  Global                WLD  2020  CDIAC 2022, BP, and Sum of countries
# 63103  Global                WLD  2021  CDIAC 2022, BP, and Sum of countries
#
#                   Carbón             Aceite                Gas        Cemento  \
# 63099  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63100  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63101  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63102  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63103  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
#
# ...

# %% [markdown]
# ## **Leyendo archivos JSON**

# %% [markdown]
# ### **Importando archivos JSON**

# %%
import pandas as pd

# %%
datos_pacientes = pd.read_json('/content/drive/MyDrive/ETL/PANDAS/PANDAS I O/pacientes.json') #todo los metodos read convierten automaticamente en un DataFrame
datos_pacientes.head()
# Out:
#    ID_paciente Enfermedad_corazon    IMC Fumador Consumo_alcohol AVC  \
# 0            0                 No  16.60      Sí              No  No
# 1            1                 No  20.34      No              No  Sí
# 2            2                 No  26.58      Sí              No  No
# 3            3                 No  24.21      No              No  No
# 4            4                 No  23.71      No              No  No
#
#    Salud_fisica  Salud_mental Dificultad_caminar Sexo_biologico Rango_edad  \
# 0             3            30                 No       Femenino      55-59
# 1             0             0                 No       Femenino     80 ó +
# 2            20            30                 No      Masculino      65-69
# 3             0             0                 No       Femenino      75-79
# 4            28             0                 Sí       Femenino      40-44
#
#      Raza Diabetes Actividad_fisica Salud_general  Horas_sueño Asma  \
# ...

# %%
#archivos JSON con información anidada, Ejemplo.
datos_pacientes2 = pd.read_json('/content/drive/MyDrive/ETL/PANDAS/PANDAS I O/pacientes_2.json')
datos_pacientes2
#A continuación se muestra el DataFrame con información Anidada. Diccionarios dentro del diccionario.
#EXISTEN HERRAMIENTAS PARA VISUALIZAR JSON COMO JSON Viewer, y JSON Crack, este último nos servira para visualizar JSON
#con información anidada.
# Out:
#                                  Investigación   Año  \
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# 2  Indicadores clave de enfermedades cardíacas  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Rango_edad': '55-59', 'Sexo_biol...
# 1  {'ID': '02', 'Rango_edad': '80 ó +', 'Sexo_bio...
# 2  {'ID': '03', 'Rango_edad': '65-69', 'Sexo_biol...

# %% [markdown]
# ### **Normalizando archivos JSON**

# %%
#Para visualizar JSON Anidados, hay que convertir en DATAFRAME.
df_normalizado = pd.json_normalize(datos_pacientes2['Pacientes'], meta=['Investigación', 'Año'])
df_normalizado
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %%
#Agregando las columnas de Año e investigación.
import json
#Leyendo el archivo json usando el módulo Python JSON
with open('/content/drive/MyDrive/ETL/PANDAS/PANDAS I O/pacientes_2.json','r') as f:
    datos = json.loads(f.read())

#Normalizando los datos con los parámetros record_path y meta
archjson_final = pd.json_normalize(datos, record_path='Pacientes', meta=['Investigación', 'Año'])
archjson_final
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud  \
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]
#
#                                  Investigación   Año
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# ...

# %% [markdown]
# ### **Escribiendo archivos en JSON**

# %%
archjson_final.to_json('archjson_final.json')
pd.read_json('archjson_final.json')
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0   1      55-59          Mujer  Blanca  16.60      Sí              No
# 1   2     80 ó +          Mujer  Blanca  20.34      No              No
# 2   3      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud  \
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]
#
#                                  Investigación   Año
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# ...

# %% [markdown]
# ## **Trabajando archivos HTML, XML

# %% [markdown]
# ### **Importando pagina WEB**

# %%
import pandas as pd

# %%
datos_html = pd.read_html('/content/drive/MyDrive/ETL/PANDAS/PANDAS I O/peliculas_wikipedia.html')
datos_html
# Out:
# [       0                      1
#  0   1998             100 Movies
#  1   1999              100 Stars
#  2   2000             100 Laughs
#  3   2001            100 Thrills
#  4   2002           100 Passions
#  5   2003  100 Heroes & Villains
#  6   2004              100 Songs
#  7   2005       100 Movie Quotes
#  8   2005              25 Scores
#  9   2006             100 Cheers
#  10  2006            25 Musicals
#  11  2007   100 Movies (Updated)
#  12  2008        AFI's 10 Top 10
#  13   vte                    vte,
#                              Film  Release year              Director  \
#  0                   Citizen Kane          1941          Orson Welles
#  1                     Casablanca          1942        Michael Curtiz
#  2                  The Godfather          1972  Francis Ford Coppola
#  3             Gone with the Wind          1939        Victor Fleming
#  4             Lawrence of Arabia          1962            David Lean
# ...

# %%
#Nos interesa la segunda tabla
top_peliculas = datos_html[1]
top_peliculas
# Out:
#                             Film  Release year              Director  \
# 0                   Citizen Kane          1941          Orson Welles
# 1                     Casablanca          1942        Michael Curtiz
# 2                  The Godfather          1972  Francis Ford Coppola
# 3             Gone with the Wind          1939        Victor Fleming
# 4             Lawrence of Arabia          1962            David Lean
# ..                           ...           ...                   ...
# 95                 The Searchers          1956             John Ford
# 96              Bringing Up Baby          1938          Howard Hawks
# 97                    Unforgiven          1992        Clint Eastwood
# 98  Guess Who's Coming to Dinner          1967        Stanley Kramer
# 99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                       Production companies  Rank
# 0                       RKO Radio Pictures     1
# ...

# %% [markdown]
# ###**Escribir archivos HTML**

# %%
top_peliculas.to_html('top_peliculas.html', index=False)

# %%
pd.read_html('top_peliculas.html')
# Out:
# [                            Film  Release year              Director  \
#  0                   Citizen Kane          1941          Orson Welles
#  1                     Casablanca          1942        Michael Curtiz
#  2                  The Godfather          1972  Francis Ford Coppola
#  3             Gone with the Wind          1939        Victor Fleming
#  4             Lawrence of Arabia          1962            David Lean
#  ..                           ...           ...                   ...
#  95                 The Searchers          1956             John Ford
#  96              Bringing Up Baby          1938          Howard Hawks
#  97                    Unforgiven          1992        Clint Eastwood
#  98  Guess Who's Coming to Dinner          1967        Stanley Kramer
#  99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                        Production companies  Rank
#  0                       RKO Radio Pictures     1
# ...

# %%
top_peliculas.to_csv('top_peliculas.csv', index=False)

# %%
datos_csv = pd.read_csv('top_peliculas.csv')
datos_csv
# Out:
#                             Film  Release year              Director  \
# 0                   Citizen Kane          1941          Orson Welles
# 1                     Casablanca          1942        Michael Curtiz
# 2                  The Godfather          1972  Francis Ford Coppola
# 3             Gone with the Wind          1939        Victor Fleming
# 4             Lawrence of Arabia          1962            David Lean
# ..                           ...           ...                   ...
# 95                 The Searchers          1956             John Ford
# 96              Bringing Up Baby          1938          Howard Hawks
# 97                    Unforgiven          1992        Clint Eastwood
# 98  Guess Who's Coming to Dinner          1967        Stanley Kramer
# 99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                       Production companies  Rank
# 0                       RKO Radio Pictures     1
# ...

# %% [markdown]
# ## **Archivos XML**

# %% [markdown]
# ###**Importando archivo XML**

# %%
import pandas as pd
datos_imdb = pd.read_xml('/content/drive/MyDrive/ETL/PANDAS/PANDAS I O/imdb_top_1000.xml')
datos_imdb.head()
# Out:
#    index                                        Poster_Link  \
# 0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1      1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2      2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3      3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4      4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# ...

# %% [markdown]
# ### **Exportando archivo XML**

# %%
datos_imdb.to_xml('peliculas_imdb.xml')

# %%
info_html = pd.read_html('https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_y_territorios_dependientes_por_poblaci%C3%B3n')
info_html
# Out:
# [     N.º                   País (o territorio dependiente)  \
#  0      1                                             India
#  1      2                                        China[12]​
#  2      3                                    Estados Unidos
#  3      4                                         Indonesia
#  4      5                                          Pakistán
#  ..   ...                                               ...
#  241  242                           Islas Cocos (Australia)
#  242  243  Islas Ultramarinas Menores de los Estados Unidos
#  243  244                               Islas Pitcairn (RU)
#  244  NaN                                             Mundo
#  245   N°                   País (o territorio dependiente)
#
#      Proyección exponencial de la población al 1/7/2025[7]​  \
#  0                                        1 417 492 000
#  1                                        1 407 934 000
#  2                                          342 181 000
# ...

# %%
len(info_html)
primera_tabla = info_html[0]
primera_tabla
# Out:
#      N.º                   País (o territorio dependiente)  \
# 0      1                                             India
# 1      2                                        China[12]​
# 2      3                                    Estados Unidos
# 3      4                                         Indonesia
# 4      5                                          Pakistán
# ..   ...                                               ...
# 241  242                           Islas Cocos (Australia)
# 242  243  Islas Ultramarinas Menores de los Estados Unidos
# 243  244                               Islas Pitcairn (RU)
# 244  NaN                                             Mundo
# 245   N°                   País (o territorio dependiente)
#
#     Proyección exponencial de la población al 1/7/2025[7]​  \
# 0                                        1 417 492 000
# 1                                        1 407 934 000
# 2                                          342 181 000
# ...

# %%
primera_tabla.to_csv('tabla1.csv', index=False)
tabla1_csv = pd.read_csv('tabla1.csv')
tabla1_csv
# Out:
#      N.º                   País (o territorio dependiente)  \
# 0      1                                             India
# 1      2                                        China[12]​
# 2      3                                    Estados Unidos
# 3      4                                         Indonesia
# 4      5                                          Pakistán
# ..   ...                                               ...
# 241  242                           Islas Cocos (Australia)
# 242  243  Islas Ultramarinas Menores de los Estados Unidos
# 243  244                               Islas Pitcairn (RU)
# 244  NaN                                             Mundo
# 245   N°                   País (o territorio dependiente)
#
#     Proyección exponencial de la población al 1/7/2025[7]​  \
# 0                                        1 417 492 000
# 1                                        1 407 934 000
# 2                                          342 181 000
# ...

# %% [markdown]
# ## **Leyendo bando de datos SQL**

# %% [markdown]
# ### **Creando un banco de datos local**

# %%
import sqlalchemy

# %%
#create engine crea todo el banco de datos, metadata guarda la información de la tabla, nombres, atributos, Table para consultar las tablas, trabajar las tablas
#inspect para inspeccionar los bancos de datos, text para convertir las querys en un tipo de datos de texto.
from sqlalchemy import create_engine, MetaData, Table, inspect, text

# %%
engine = create_engine('sqlite:///:memory:') #"memory" para ejecutar con la memoria local de google colab

# %%
import pandas as pd

# %%
archivo = '/content/drive/MyDrive/ETL/PANDAS/PANDAS I O/clientes_banco.csv'

# %%
dt = pd.read_csv(archivo)

# %%
dt.head()
# Out:
#    ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0     5008804    32    Nivel superior  Relación-estable               2
# 1     5008805    32    Nivel superior  Relación-estable               2
# 2     5008806    58  Nivel intermedio            Casado               2
# 3     5008808    52  Nivel intermedio           Soltero               1
# 4     5008809    52  Nivel intermedio           Soltero               1
#
#   Categoria_de_renta  Ocupacion  Años_empleado  Rendimiento_anual  \
# 0           Empleado       Otro             12           427500.0
# 1           Empleado       Otro             12           427500.0
# 2           Empleado  Seguridad              3           112500.0
# 3   Business Partner     Ventas              8           270000.0
# 4   Business Partner     Ventas              8           270000.0
#
#    Tiene_carro                  Vivienda
# 0            1    Departamento alquilado
# 1            1    Departamento alquilado
# ...

# %%
dt.to_sql('Clientes', engine, index=False) #se le coloca un nombre y engine que es el motor
# Out:
# 438463

# %%
inspector = inspect(engine) #revisa todo lo que hay en el motor engine y se guarda en la variable

# %%
print(inspector.get_table_names()) #imprime el nombre de las tablas, .get_table_names es una función propia de inspect
#no se puede ejecutar en un DataFrame, ya que es una funcion de tipo inspect.
# Out:
# ['Clientes']

# %% [markdown]
# ### **Consultas SQL**

# %%
query = 'SELECT * FROM Clientes WHERE Categoria_de_renta = "Empleado"'
#esto quiere decir "selecciona toda las columnas (*eso significa asterisco), desde la tabla clientes" DONDE la columna "Categoria_de_renta" sea igual a Empleado.

# %%
#Lo anterior es solo una variable de texto, por lo que, para leer la consulta hacemos lo siguiente, es decir, esta función lee consultas
empleados = pd.read_sql(sql=text(query), con=engine.connect()) #dentro del read agregamos variable sql = text(query), es decir sq
#va a leer el texto que esta en la variable query como una consulta, posteriormente se agrega igual al motor

# %%
#examinamos el tipo de la variable empleados
type(empleados)
# Out:
# pandas.core.frame.DataFrame

# %%
empleados
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
#guardando
empleados.to_sql('Empleados', con=engine.connect(), index=False) #con=engine.connect() utilizando la conexion engine de sql
# Out:
# 226059

# %%
pd.read_sql_table('Empleados', con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
#Filtrando algunas columnas en especifico.
pd.read_sql_table('Empleados', con=engine.connect(), columns=['ID_Cliente','Grado_estudio','Rendimiento_anual'])
# Out:
#         ID_Cliente     Grado_estudio  Rendimiento_anual
# 0          5008804    Nivel superior           427500.0
# 1          5008805    Nivel superior           427500.0
# 2          5008806  Nivel intermedio           112500.0
# 3          5008815    Nivel superior           270000.0
# 4          5112956    Nivel superior           270000.0
# ...            ...               ...                ...
# 226054     6837905  Nivel intermedio           355050.0
# 226055     6837906  Nivel intermedio           355050.0
# 226056     6839936  Nivel intermedio           135000.0
# 226057     6840222  Nivel intermedio           103500.0
# 226058     6842885  Nivel intermedio           121500.0
#
# [226059 rows x 3 columns]

# %% [markdown]
# ### **Actualizando un banco de datos**

# %%
query =
